# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrpavangit18/GRIP-TASK3/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
SampleSuperstore.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
#checking dimensionality
SampleSuperstore.shape
# Out:
# (9994, 13)

# %%
#checking duplicate 
SampleSuperstore.duplicated().sum()
# Out:
# 17

# %%
#Removing duplicates
SampleSuperstore.drop_duplicates(inplace=True)

# %%
SampleSuperstore.shape
# Out:
# (9977, 13)

# %%
#Checking Descriptive Statistics
SampleSuperstore.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %%
#checking information
SampleSuperstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
#Checking Null values in each column
SampleSuperstore.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Checking columns
SampleSuperstore.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#Checking number of unique values in columns
SampleSuperstore.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
SampleSuperstore.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(10,6))
sns.heatmap(SampleSuperstore.corr(),annot=True)
plt.title("Heat Map on Sample of the Superstore")
plt.show()

# %%
# Relation among Sales, Profit and Discount
SampleSuperstore.plot(kind="scatter",x="Sales",y="Profit",c="Discount",colormap="ocean",figsize=(16,7))
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.title("Relation among Sales, Profit and Discount")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x="Discount",y="Profit",data=SampleSuperstore)
plt.show()

# %%
sns.countplot(x="Category",data=SampleSuperstore)

# %% [markdown]
# The Office supplies category is the most selling category

# %%
cat=SampleSuperstore["Category"].value_counts()
print(cat)
print("\n")

plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
(SampleSuperstore["Category"].value_counts()).plot(kind="bar",color="purple")

plt.subplot(1,2,2)
SampleSuperstore["Category"].value_counts().plot.pie(autopct="%.2f", explode=(0.05,0.05,0.05))
plt.tight_layout()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %% [markdown]
# The Office supplies category has a 60.26% share from the category

# %%
# plotting Sub category items.

plt.figure(figsize=(16,4))
sns.countplot(x="Sub-Category",data=SampleSuperstore)

# %%
SampleSuperstore["Sub-Category"].value_counts()/len(SampleSuperstore["Sub-Category"])*100

#plt.figure(figsize=(10,10))
#SampleSuperstore["Sub-Category"].value_counts().plot.pie(autopct="%.2f")
# Out:
# Binders        15.255087
# Paper          13.621329
# Furnishings     9.582039
# Phones          8.910494
# Storage         8.479503
# Art             7.968327
# Accessories     7.767866
# Chairs          6.164178
# Appliances      4.670743
# Labels          3.638368
# Tables          3.197354
# Envelopes       2.545855
# Bookcases       2.285256
# Fasteners       2.175003
# Supplies        1.904380
# Machines        1.152651
# Copiers         0.681568
# Name: Sub-Category, dtype: float64

# %% [markdown]
# Binders is the most selling item and Copier is least selling.

# %%
seg=SampleSuperstore["Segment"].value_counts()
print(seg)
print("\n")

plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
(SampleSuperstore["Segment"].value_counts()*100).plot(kind="bar",color="purple")

plt.subplot(1,2,2)
SampleSuperstore["Segment"].value_counts().plot.pie(autopct="%.2f", explode=(0.05,0.05,0.05))
plt.tight_layout()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %% [markdown]
# The consumer segment buys more from superstore compared to other segments

# %%
sns.countplot(x='Segment',data=SampleSuperstore,hue="Category",palette='magma')
plt.legend(loc=0)
plt.tight_layout()

# %% [markdown]
# Office supplies are the most selling category in all the segments

# %%
sns.countplot(x='Region',data=SampleSuperstore,hue="Category",palette='magma')
plt.legend(loc=0)
plt.tight_layout()

# %% [markdown]
# Office supplies are the most selling category in all the regions

# %%
sns.countplot(x='Region',data=SampleSuperstore,hue="Ship Mode",palette='magma')
plt.legend(loc=0)
plt.tight_layout()

# %% [markdown]
# Standard class is the most preffered shipping mode in all the regions

# %% [markdown]
# Most selling top 10 products(Sub-Category)

# %%
#Grouping Sub Category based on Quantity
mostSell=(SampleSuperstore.groupby("Sub-Category").sum()["Quantity"])

#sorting 
mostSelltop10=mostSell.sort_values( ascending=False)

#Plotting top 10 selling products
plt.figure(figsize=(16,5))
mostSelltop10.head(10).plot(kind="bar", color="purple")

# %% [markdown]
# Top 10 products by Profit

# %%
profitProduct=(SampleSuperstore.groupby("Sub-Category").sum()["Profit"])

#sorting 
top10profitProduct=profitProduct.sort_values( ascending=False)

#Plotting top 10 selling products
plt.figure(figsize=(16,5))
top10profitProduct.head(10).plot(kind="bar", color="purple")

# %% [markdown]
# Loss making products

# %%
#Plotting loss making products
plt.figure(figsize=(16,5))
top10profitProduct.tail(7).plot(kind="bar", cmap="plasma")

# %% [markdown]
# Which are the most profitable Category and sub-category

# %%
profiCatSubcat=(SampleSuperstore.groupby(["Category", "Sub-Category"]).sum()["Profit"])

#sorting 
mostprofiCatSubcat=profiCatSubcat.sort_values( ascending=False)

#Plotting
plt.figure(figsize=(16,5))
mostprofiCatSubcat.plot(kind="bar",cmap="ocean")

# %% [markdown]
# Which are the most Saled Category and sub-category

# %%
saleCatSubcat=(SampleSuperstore.groupby(["Category", "Sub-Category"]).sum()["Sales"])

#sorting 
mostsaleCatSubcat=saleCatSubcat.sort_values( ascending=False)

#Plotting
plt.figure(figsize=(16,5))
mostsaleCatSubcat.plot(kind="bar",cmap="ocean")

# %% [markdown]
# Profit and Sales in Ship Mode

# %%
shipingProfit=SampleSuperstore.groupby("Ship Mode").sum()[["Profit","Sales"]]

shipingProfit.plot(kind="bar",figsize=(16,7))

# %% [markdown]
# Region wise profit distribution

# %%
regionProfit=SampleSuperstore.groupby("Region").sum()["Profit"]

plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
regionProfit.plot(kind="bar")

plt.subplot(1,2,2)
regionProfit.plot.pie(autopct="%.2f", explode=(0.05,0.05,0.05,0.05))

plt.tight_layout()

# %% [markdown]
# Segment wise profit distribution

# %%
segmentProfit=(SampleSuperstore.groupby("Segment").sum()["Profit"])

plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
segmentProfit.plot(kind="bar")

plt.subplot(1,2,2)
segmentProfit.plot.pie(autopct="%.2f", explode=(0.05,0.05,0.05))

plt.tight_layout()

# %% [markdown]
# Category wise profit distribution

# %%
categoryProfit=(SampleSuperstore.groupby("Category").sum()["Profit"])

plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
categoryProfit.plot(kind="bar")

plt.subplot(1,2,2)
categoryProfit.plot.pie(autopct="%.2f", explode=(0.05,0.05,0.05))

plt.tight_layout()

# %% [markdown]
# Checking profit in All States

# %%
statesProfit=SampleSuperstore.groupby("State").sum()["Profit"]

#Plotting
plt.figure(figsize=(16,5))
statesProfit.plot(kind="bar",cmap="jet")

# %% [markdown]
# Checking Sales in All States

# %%
statesProfit=SampleSuperstore.groupby("State").sum()["Sales"]

#Plotting
plt.figure(figsize=(16,5))
statesProfit.plot(kind="bar",cmap="jet")

# %% [markdown]
# Checking the role of discount on profit

# %%
discountProfit=SampleSuperstore.groupby("Discount").sum()["Profit"]

#Plotting
plt.figure(figsize=(16,5))
discountProfit.plot(kind="bar",color="red")

# %% [markdown]
# Checking the role of discount on sales

# %%
salesProfit=SampleSuperstore.groupby("Discount").sum()["Sales"]

#Plotting
plt.figure(figsize=(16,5))
salesProfit.plot(kind="bar",color="blue")
